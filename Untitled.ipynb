# %%
pd.read_csv

# %%
import pandas as pd
from glob import glob

groups = pd.read_csv('data\\groups.csv', encoding='latin1', index_col='group_id')
files = glob('data\\*.csv')

# %%
gdata = pd.DataFrame()
for g in files:
    if not 'group' in g:
        tdf = pd.read_csv(g)
        gdata = gdata.append(td)
# Out:
#      group_id                                         group_name  num_members  \
# 0      339011                            Nashville Hiking Meetup        15828
# 1    19728145                   Stepping Out Social Dance Meetup         1778
# 2     6335372                                   Nashville soccer         2866
# 3    20040517                         Franklin 40+ Out and About         1274
# 4     9452822                            615 LOL (Live Out Loud)         3213
# 5    24440003         Outgoing Introverts of Nashville (20s/30s)          721
# 6    10016242                                             NashJS         1976
# 7    11077852                          Sunday Assembly Nashville          918
# 8    21174496          20's & 30's Women looking for girlfriends         2763
# 9     1763190                            Nashville Tennis Meetup         1562
# 10   19115644                             Sex Positive Nashville          719
# ...
