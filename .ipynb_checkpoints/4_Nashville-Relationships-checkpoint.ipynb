# %%
import pandas as pd
import numpy as np
import networkx as nx
from pprint import pprint


# create a "members" dataset
memberships = pd.read_csv('data\\memberships.csv', parse_dates=['joined','visited'])
members = memberships[['member_id', 'name', 'hometown', 'city','state', 'lat', 'lon']].groupby('member_id').first()

# read in group information and trim down to only groups with edges
groups = pd.read_csv('data\\groups.csv', index_col='group_id')
groups = groups.loc[memberships.group_id.unique()]

# Read in Event Data
rsvps = pd.read_csv('data/rsvps.csv')
events = pd.read_csv('data/events.csv')

# %%
# All members 
pynash_member_ids = memberships.loc[memberships.group_id == 11625832].member_id
pynash_members = members.loc[pynash_member_ids]

# One event
lunch_rsvps = rsvps.loc[rsvps.event_id == 'cldxflywnbgb']

# %%
# Build DataFrame from pynash_rsvps

g = nx.from_pandas_dataframe(rsvps, source='member_id', target='event_id')
# Out:
# ---------------------------------------------------------------------------
# AmbiguousSolution                         Traceback (most recent call last)
# <ipython-input-5-679f393f4c83> in <module>()
#       2
#       3 g = nx.from_pandas_dataframe(rsvps, source='member_id', target='event_id')
# ----> 4 member_nodes, event_nodes = nx.bipartite.sets(g)
#       5 print('There are {} members and {} events.'.format(len(member_nodes), len(event_nodes)))
#
# C:\Users\stkba\Anaconda3\envs\py3\lib\site-packages\networkx\algorithms\bipartite\basic.py in sets(G, top_nodes)
#     201         if not is_connected(G):
#     202             msg = 'Disconnected graph: Ambiguous solution for bipartite sets.'
# --> 203             raise nx.AmbiguousSolution(msg)
#     204         c = color(G)
#     205         X = {n for n, is_top in c.items() if is_top}
#
# AmbiguousSolution: Disconnected graph: Ambiguous solution for bipartite sets.

# %%
nx.is_connected(g)
# Out:
# False

# %%
# Get the connected subcomponents of the main graph
components = list(nx.connected_components(g))
connected_nodes = components[0]
g = g.subgraph(connected_nodes)

# %%
print('Graph is connected:', nx.is_connected(g))
print('Graph is bipartite:', nx.is_bipartite(g))
# Out:
# Graph is connected: True
# Graph is bipartite: True

# %%
member_nodes, event_nodes = nx.bipartite.sets(g)
print('There are {} members and {} events.'.format(len(member_nodes), len(event_nodes)))
# Out:
# There are 24490 members and 18885 events.

# %%
# Out:
# array([  6144606,  65072762, 225546676, ..., 155191662, 193053558,
#        185487853], dtype=int64)

# %%
pos = nx.random_layout(gm)

# %%
gm = nx.bipartite.weighted_projected_graph(g, member_nodes, ratio=False)
ge = nx.bipartite.weighted_projected_graph(g, event_nodes, ratio=False)

# %%
df_members = pd.DataFrame(index=member_nodes)
df_members['in_pynash'] = [True if m in pynash_member_ids.values else False for m in member_nodes]
df_members['degree'] = pd.Series(dict(gm.degree))

# %%
df_members.loc[df_members.in_pynash==True].sort_values(by='degree', ascending=False).join(members)
# Out:
#            in_pynash  degree                 name         hometown  \
# 71851852        True    1677         Rick Murdock              NaN
# 8539046         True    1547              Shalini              NaN
# 6160486         True    1457              yan fei              NaN
# 184547023       True    1362         Chris Jarvis              NaN
# 138867992       True    1322           Trent Hand              NaN
# 175300482       True    1237                  Rav              NaN
# 127214502       True    1222      Bryan P Marlowe              NaN
# 13606604        True    1191        Alex Simonian        Nashville
# 55029192        True    1166               Josh E          Augusta
# 11872972        True    1149                 Alan              NaN
# 217160398       True    1137            Joel Legg              NaN
# 203244569       True    1122            Calvin J.    Nashville, TN
# 8731661         True    1118           Jeff Bowen       Durham, NC
# 221191725       True    1103             Omar Ali              NaN
# 57907252        True    1092          Chad Upjohn              NaN
# 184019319       True    1085      Brian Stumbaugh        Nashville
# 4169858         True    1079     Gaines Kergosien        Nashville
# 194099532       True    1034         Mike Meadows              NaN
# 187254868       True    1018       Andrew Clement  Chattanooga, TN
# 71854632        True    1004       Joseph Wichman              NaN
# 75873682        True     995               Bayron              NaN
# 206481851       True     990          Adia Tigney              NaN
# 217856665       True     983        Luke Woodward              NaN
# 76743532        True     969          John Harris              NaN
# 135113782       True     968        Justin Hoover              NaN
# 183564319       True     945          Ryan Murray              NaN
# 126309962       True     945        Aliya Gifford              NaN
# 14368154        True     945     Justin Threlkeld              NaN
# 208429247       True     929    Garrett Vangilder        Nashville
# 2606806         True     921         James Porter              NaN
# ...              ...     ...                  ...              ...
# 25020832        True      10       Harisankar P S        Ernakulam
# 192158461       True      10      Light Whitewolf              NaN
# 200777643       True      10        Stephen Brady              NaN
# 214350596       True      10       Sulaiman Allen              NaN
# 238307094       True      10      Jessica Whitman              NaN
# 198667802       True       9        Sanjay Mishra              NaN
# 229049863       True       9               Ray Li              NaN
# 7606093         True       8               Ben S.        Davis, CA
# 204294527       True       8               Ashish              NaN
# 28652082        True       8         Mike Burrell       Muncie, IN
# 59507012        True       7                 Aron        nashville
# 227987255       True       7            Johnathan              NaN
# 22199791        True       6           Bryan Kemp       Jackson TN
# 197628527       True       5      Michael Kennedy              NaN
# 4304748         True       5                Karla              NaN
# 107960352       True       5           Enam Haque        Brentwood
# 237639679       True       5         Sarah Maddox              NaN
# 233236221       True       4        Carol Kraemer              NaN
# 95204562        True       4       Zach McCormick              NaN
# 14219098        True       4        Almae English              NaN
# 3517021         True       4               Dave D        Tampa, FL
# 95625892        True       4    Dustin Keith Weld              NaN
# 189347481       True       4        Mike McDonald              NaN
# 189349302       True       3        Justin Sadler              NaN
# 182986549       True       3             Nathan C              NaN
# 196014675       True       2      Andrew Bergeron              NaN
# 204871578       True       2  AnaKatarina Lalonde              NaN
# 224989394       True       2                Jacob              NaN
# 81213252        True       1    Manuel Izturriaga              NaN
# 14474678        True       1                 Al H              NaN
#
#                      city state    lat     lon
# 71851852         Franklin    TN  35.92  -86.89
